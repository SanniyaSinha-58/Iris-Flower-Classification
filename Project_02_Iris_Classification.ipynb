# %% [markdown]
# ## Iris Flower Classification Using Machine Learning

# %% [markdown]
# ## Objective:
#
# The objective of this project is to build and evaluate machine learning models for classifying Iris flower into different species based on their physical charateristics.The project uses data analysis,visualization and classification algorithms such as Logistic Regression,K-Nearest Neighbors(KNN) and Random Forest.

# %%
# !ls
# Out:
# Iris.csv  sample_data

# %%
import pandas as pd

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %%
df['Species'].value_counts().plot(kind='bar')
plt.title('Distribution of Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
df['SepalLengthCm'].plot(kind='hist',bins=10)
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
df['PetalLengthCm'].plot(kind='hist',bins=10)
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length(cm)')
plt.ylabel('Frequency')
plt.show()

# %%
x=df.drop(['Id','Species'],axis=1)
y=df['Species']

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(
    x,y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## Machine Learning Models

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression(max_iter=200)
lr.fit(x_train,y_train)
lr_score= lr.score(x_test,y_test)
print("Logistic Regression Accuracy:",lr_score)
# Out:
# Logistic Regression Accuracy: 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
knn_score=knn.score(x_test,y_test)
print("KINN Accuracy:",knn_score)
# Out:
# KINN Accuracy: 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
rf_score=rf.score(x_test,y_test)
print("Random Forest Accuracy:",rf_score)
# Out:
# Random Forest Accuracy: 1.0

# %%
results={
    'Logistic Regeression':lr_score,
    'KINN':knn_score,
    'Random Forest':rf_score
}
print(results)
# Out:
# {'Logistic Regeression': 1.0, 'KINN': 1.0, 'Random Forest': 1.0}

# %% [markdown]
# ## Model Evaluation

# %%
import matplotlib.pyplot as plt
models=['Logistic Regression','KINN','Random Forest']
scores=[lr_score,knn_score,rf_score]
plt.bar(models,scores)
plt.title('Model Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
y_pred=rf.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %% [markdown]
# ## Insights
#
# 1.The Iris Dataset contains 150 flower samples belonging to three species .
#
# 2.The dataset is balanced,with 50 samples for each species.
#
# 3.No missing values were found in the dataset.
#
# 4.Histograms showed the distribution of Sepal Length and Petal length among flowers.
#
# 5.Logistic Regression,KNNN and Random Forest achieved 100% accuracy on the test set.
#
# 6.The confusion Matrix showed zero misclassifications,indicating excellent model performance.

# %% [markdown]
# ## Conclusion
#
# This project successfully classified Iris flower  species using machine learning techniques.Data preprocessing,visualization,and model training were performed.Three classification algorithms (Logistic Regression,KINN,and Random Forest) were evaluated and all achieved 100% accuracy.The confusion matrix confirmed that all test samples were classified correctly .This demonstrates that machine learning can effectively solve flower species classification problems using the Iris dataset.
